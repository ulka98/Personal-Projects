# %% [markdown]
# #   Problem Statement 4 :3. Find a correlation between pH and Quality.
# # Fact: Winemakers use pH as a way to measure ripeness in relation to acidity.Low pH wines will taste tart and crisp, while higher pH wines are more susceptible to bacterial growth.Most wine pH's fall around 3 or 4; about 3.0 to 3.4 is desirable for white wines, while about 3.3 to 3.6 is best for reds.
#
# # Expected analysis: Higher quality wines should contain pH between 3 and 3.4
#
# # 3. pH vs residual sugar.
#
# # Fact: The perfect way to contextualize how sweetness reduces the sensation of acidity in wine is to compare how you react to tasting a raw lemon to Coca-Cola. Technically, they have the same pH (around 2.5), but since coke is sweet it’s not as intense.
#
# # Expected analysis: Should have indirect proportion
# # (For saving the plots use : plt.savefig('filename.jpg'))

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from numpy.random import randint,randn

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
wineset_frame_org = pd.read_csv('winequality-red.csv', sep = ';')

# %%
wineset_frame_org.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
wineset_frame_org['pH'].corr(wineset_frame_org['quality'])
# Out:
# -0.057731391205382156

# %%
wineset_frame_org['pH'].corr(wineset_frame_org['residual sugar'],method='pearson')
# Out:
# -0.085652422218871649

# %% [markdown]
# Since the corr value isn't near to -1 or +1, both the factors are necessary for analysis and we can't ignore both. Also both of the relations above has negative pearson's coefficient, therefore, rescective variables posses inverse relationship

# %%
qualities = wineset_frame_org.quality.tolist()
pH_values = wineset_frame_org.pH.tolist()
plt.scatter(pH_values,qualities,c='cyan',marker = 's',s =20)
plt.xlabel('pH')
plt.ylabel('quality')
plt.grid()
plt.show()

# %%
cor = wineset_frame_org.corr()

# %%
cor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
cor.columns
# Out:
# Index([u'fixed acidity', u'volatile acidity', u'citric acid',
#        u'residual sugar', u'chlorides', u'free sulfur dioxide',
#        u'total sulfur dioxide', u'density', u'pH', u'sulphates', u'alcohol',
#        u'quality'],
#       dtype='object')

# %%
cor.plot(kind='density', subplots=True, layout=(4,4), sharex=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B935630>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010810668>]], dtype=object)

# %%
limited_frame = DataFrame(wineset_frame_org,columns=['pH','quality'])

# %%
quality7 = limited_frame[limited_frame['quality']==7]

# %%
quality8 = limited_frame[limited_frame['quality']==8]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cor, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,12,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(cor.columns)
ax.set_yticklabels(cor.columns)
plt.show()

# %%
conditions = [(wineset_frame_org['quality'] >= 7),(wineset_frame_org['quality'] <= 4)]
rating = ['good', 'bad']
wineset_frame_org['rating'] = np.select(conditions, rating, default='average')
wineset_frame_org.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
group1 = wineset_frame_org['pH'].groupby(wineset_frame_org['rating']=='good')

# %%
good_frame = DataFrame(wineset_frame_org, columns = ['pH','quality','rating'])

# %%
good_frame.sort_values('rating').head(10)
# Out:
#         pH  quality   rating
# 0     3.51        5  average
# 1027  3.49        5  average
# 1026  3.41        6  average
# 1025  3.33        6  average
# 1023  3.27        6  average
# 1022  3.35        5  average
# 1021  3.20        6  average
# 1020  3.20        6  average
# 1019  3.53        5  average
# 1028  3.37        6  average

# %%
good_frame.sort_values('rating').tail(10)
# Out:
#         pH  quality rating
# 828   3.46        8   good
# 606   3.34        7   good
# 826   3.40        7   good
# 986   3.19        7   good
# 1449  3.23        8   good
# 1450  3.23        7   good
# 1451  3.33        7   good
# 1452  3.35        7   good
# 1162  3.14        7   good
# 1081  3.01        7   good

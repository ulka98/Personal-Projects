# %% [markdown]
# #  Problem Statement 2: Which quality of wine is highly acidic?
# #  Problem Statement 3: Quality vs Total Acidity Bar and Pie chart

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from numpy.random import randint,randn
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
wineset_dframe = pd.read_csv('winequality-red.csv', sep = ';')

# %%
wineset_dframe.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
limited_frame = DataFrame(wineset_dframe,columns = ['fixed acidity','volatile acidity','citric acid','pH','quality'])

# %%
limited_frame.head()
# Out:
#    fixed acidity  volatile acidity  citric acid    pH  quality
# 0            7.4              0.70         0.00  3.51        5
# 1            7.8              0.88         0.00  3.20        5
# 2            7.8              0.76         0.04  3.26        5
# 3           11.2              0.28         0.56  3.16        6
# 4            7.4              0.70         0.00  3.51        5

# %%
add = limited_frame['fixed acidity']+limited_frame['volatile acidity']+limited_frame['citric acid']

# %%
limited_frame = DataFrame(wineset_dframe,columns = ['fixed acidity','volatile acidity','citric acid','pH','sum','quality'])

# %%
limited_frame['sum'] = add

# %%
limited_frame.rename(columns = {'sum':'Total_Acidity'},inplace=True)

# %%
max_acid = limited_frame['Total_Acidity'].max()

# %%
limited_frame['quality'].max()
# Out:
# 8

# %%
limited_frame.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid           pH  \
# count    1599.000000       1599.000000  1599.000000  1599.000000
# mean        8.319637          0.527821     0.270976     3.311113
# std         1.741096          0.179060     0.194801     0.154386
# min         4.600000          0.120000     0.000000     2.740000
# 25%         7.100000          0.390000     0.090000     3.210000
# 50%         7.900000          0.520000     0.260000     3.310000
# 75%         9.200000          0.640000     0.420000     3.400000
# max        15.900000          1.580000     1.000000     4.010000
#
#        Total_Acidity      quality
# count    1599.000000  1599.000000
# mean        9.118433     5.636023
# std         1.832708     0.807569
# min         5.270000     3.000000
# 25%         7.827500     5.000000
# 50%         8.720000     6.000000
# 75%        10.070000     6.000000
# max        17.045000     8.000000

# %%
max_acid
# Out:
# 17.045000000000002

# %%
max_acid_index = limited_frame['Total_Acidity'].idxmax()

# %%
max_acid_index
# Out:
# 442

# %% [markdown]
# Quality of wine with highest acidity

# %%
limited_frame.loc[422,'quality']
# Out:
# 5.0

# %%
quality3_frame = limited_frame[limited_frame['quality']==3]

# %%
quality3_frame
# Out:
#       fixed acidity  volatile acidity  citric acid    pH  Total_Acidity  \
# 459            11.6             0.580         0.66  3.25         12.840
# 517            10.4             0.610         0.49  3.16         11.500
# 690             7.4             1.185         0.00  3.63          8.585
# 832            10.4             0.440         0.42  3.38         11.260
# 899             8.3             1.020         0.02  3.48          9.340
# 1299            7.6             1.580         0.00  3.50          9.180
# 1374            6.8             0.815         0.00  3.32          7.615
# 1469            7.3             0.980         0.05  3.31          8.330
# 1478            7.1             0.875         0.05  3.40          8.025
# 1505            6.7             0.760         0.02  3.55          7.480
#
#       quality
# 459         3
# 517         3
# 690         3
# 832         3
# 899         3
# 1299        3
# 1374        3
# 1469        3
# 1478        3
# 1505        3

# %%
quality3_values = quality3_frame.quality.tolist()

# %%
quality4_frame = limited_frame[limited_frame['quality']==4]

# %%
quality4_values = quality4_frame.quality.tolist()

# %%
quality5_frame = limited_frame[limited_frame['quality']==5]

# %%
quality5_values = quality5_frame.quality.tolist()

# %%
quality6_frame = limited_frame[limited_frame['quality']==6]

# %%
quality6_values = quality6_frame.quality.tolist()

# %%
quality7_frame = limited_frame[limited_frame['quality']==7]

# %%
quality7_values = quality7_frame.quality.tolist()

# %%
quality8_frame = limited_frame[limited_frame['quality']==8]

# %%
quality8_values = quality8_frame.quality.tolist()

# %%
total_acidity3 = quality3_frame.Total_Acidity.tolist()

# %%
total_acidity4 = quality4_frame.Total_Acidity.tolist()

# %%
total_acidity5 = quality5_frame.Total_Acidity.tolist()

# %%
total_acidity6 = quality6_frame.Total_Acidity.tolist()

# %%
total_acidity7 = quality7_frame.Total_Acidity.tolist()

# %%
total_acidity8 = quality8_frame.Total_Acidity.tolist()

# %%
qualitylist = limited_frame.quality.tolist()
totalaciditylist = limited_frame.Total_Acidity.tolist()
plt.bar(qualitylist,totalaciditylist, color = 'blue', align = 'center')
plt.xlabel('Qualities')
plt.ylabel('Total Acidity')
plt.show()

# %%
acidity = {'3':total_acidity3,'4':total_acidity4,'5':total_acidity5,'6':total_acidity6,'7':total_acidity7,'8':total_acidity8}

# %%
plt.pie(total_acidity3,labels=quality3_values,autopct='%1.2f%%',radius = 1)
plt.show()

# %%
plt.pie(total_acidity4,labels=quality4_values,autopct='%1.2f%%',radius = 1.5)
plt.show()

# %%
plt.pie(total_acidity5,labels=quality5_values,autopct='%0.5f%%',radius = 1.5)
plt.show()

# %%
plt.pie(total_acidity6,labels=quality6_values,autopct='%10f%%',radius = 1.5)
plt.show()

# %%
plt.pie(total_acidity7,labels=quality7_values,autopct='%1.2f%%',radius = 1.5)
plt.show()

# %%
plt.rcParams['lines.linestyle'] = '-'
plt.pie(total_acidity8,labels=quality8_values,autopct='%1.2f%%',radius = 1.5)
plt.show()
